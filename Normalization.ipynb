# %% [markdown]
# # 1 Import Libiraries

# %%
import pandas as pd

# %%
train = pd.read_csv('C:/Users/ar194371/Documents/Data Mining/Data/train_after_missing_value.csv')

# %%
test = pd.read_csv('C:/Users/ar194371/Documents/Data Mining/Data/test_after_missing_value.csv')

# %%
continuous_features = ['TransactionDT','TransactionAmt' , 'dist1', 'C1', 'C2', 'C3', 'D1', 'D2', 'D3', 'V1', 'V2', 'V3']

# %% [markdown]
# # 2 Normalize Train Datasets

# %%
from turtle import shape

train.shape # (# rows, # columns)
# Out:
# (553287, 256)

# %%
train[continuous_features].describe()
# Out:
#        TransactionDT  TransactionAmt          dist1             C1  \
# count   5.532870e+05   553287.000000  553287.000000  553287.000000
# mean    7.505726e+06      134.604049      54.088609      13.871662
# std     4.605176e+06      238.827294     246.330358     129.830467
# min     8.640000e+04        0.250977       0.000000       0.000000
# 25%     3.173272e+06       42.937500       8.000000       1.000000
# 50%     7.437624e+06       68.500000       8.000000       1.000000
# 75%     1.140605e+07      125.000000       8.000000       3.000000
# max     1.581113e+07    31936.000000   10288.000000    4684.000000
#
#                   C2             C3             D1             D2  \
# count  553287.000000  553287.000000  553287.000000  553287.000000
# mean       15.066244       0.006010      92.737858     137.363450
# std       150.597731       0.155468     156.920247     132.306159
# min         0.000000       0.000000       0.000000       0.000000
# 25%         1.000000       0.000000       0.000000      90.000000
# 50%         1.000000       0.000000       2.000000     103.000000
# 75%         3.000000       0.000000     118.000000     104.000000
# max      5692.000000      26.000000     640.000000     640.000000
#
#                   D3             V1             V2             V3
# count  553287.000000  553287.000000  553287.000000  553287.000000
# mean       19.260494       0.999971       1.025395       1.043856
# std        47.664016       0.005377       0.181369       0.243586
# min         0.000000       0.000000       0.000000       0.000000
# 25%         7.000000       1.000000       1.000000       1.000000
# 50%         8.000000       1.000000       1.000000       1.000000
# 75%        10.000000       1.000000       1.000000       1.000000
# max       819.000000       1.000000       8.000000       9.000000

# %%
import numpy as np
train_contifeatures = pd.DataFrame((train[continuous_features]), columns=continuous_features)
train_contifeatures.hist(figsize=(20, 20))
# Out:
# array([[<Axes: title={'center': 'TransactionDT'}>,
#         <Axes: title={'center': 'TransactionAmt'}>,
#         <Axes: title={'center': 'dist1'}>],
#        [<Axes: title={'center': 'C1'}>, <Axes: title={'center': 'C2'}>,
#         <Axes: title={'center': 'C3'}>],
#        [<Axes: title={'center': 'D1'}>, <Axes: title={'center': 'D2'}>,
#         <Axes: title={'center': 'D3'}>],
#        [<Axes: title={'center': 'V1'}>, <Axes: title={'center': 'V2'}>,
#         <Axes: title={'center': 'V3'}>]], dtype=object)

# %% [markdown]
# # 2.1 Z-score Normalization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
train_data_dropped_z_score_scaled = pd.DataFrame(scaler.fit_transform(train[continuous_features]), columns=continuous_features)
train_data_dropped_z_score_scaled.describe()
# Out:
#        TransactionDT  TransactionAmt         dist1            C1  \
# count   5.532870e+05    5.532870e+05  5.532870e+05  5.532870e+05
# mean    9.534056e-17   -1.680788e-16 -5.907416e-18 -8.013538e-18
# std     1.000001e+00    1.000001e+00  1.000001e+00  1.000001e+00
# min    -1.611086e+00   -5.625538e-01 -2.195777e-01 -1.068445e-01
# 25%    -9.407800e-01   -3.838197e-01 -1.871010e-01 -9.914216e-02
# 50%    -1.478806e-02   -2.767862e-01 -1.871010e-01 -9.914216e-02
# 75%     8.469445e-01   -4.021340e-02 -1.871010e-01 -8.373744e-02
# max     1.803495e+00    1.331566e+02  4.154551e+01  3.597101e+01
#
#                  C2            C3            D1            D2            D3  \
# count  5.532870e+05  5.532870e+05  5.532870e+05  5.532870e+05  5.532870e+05
# mean   1.361274e-17 -1.643803e-18  5.198526e-17  4.520458e-17 -2.642927e-17
# std    1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min   -1.000431e-01 -3.865465e-02 -5.909877e-01 -1.038225e+00 -4.040891e-01
# 25%   -9.340285e-02 -3.865465e-02 -5.909877e-01 -3.579840e-01 -2.572277e-01
# 50%   -9.340285e-02 -3.865465e-02 -5.782424e-01 -2.597270e-01 -2.362475e-01
# 75%   -8.012242e-02 -3.865465e-02  1.609873e-01 -2.521688e-01 -1.942871e-01
# max    3.769605e+01  1.671989e+02  3.487521e+00  3.799045e+00  1.677870e+01
#
#                  V1            V2            V3
# count  5.532870e+05  5.532870e+05  5.532870e+05
# mean   4.411665e-15 -1.875990e-16 -4.520458e-17
# std    1.000001e+00  1.000001e+00  1.000001e+00
# min   -1.859555e+02 -5.653650e+00 -4.285368e+00
# 25%    5.377631e-03 -1.400214e-01 -1.800435e-01
# 50%    5.377631e-03 -1.400214e-01 -1.800435e-01
# 75%    5.377631e-03 -1.400214e-01 -1.800435e-01
# max    5.377631e-03  3.845538e+01  3.266255e+01

# %%
train_data_dropped_z_score_scaled.hist(figsize=(20, 20))
# Out:
# array([[<Axes: title={'center': 'TransactionDT'}>,
#         <Axes: title={'center': 'TransactionAmt'}>,
#         <Axes: title={'center': 'dist1'}>],
#        [<Axes: title={'center': 'C1'}>, <Axes: title={'center': 'C2'}>,
#         <Axes: title={'center': 'C3'}>],
#        [<Axes: title={'center': 'D1'}>, <Axes: title={'center': 'D2'}>,
#         <Axes: title={'center': 'D3'}>],
#        [<Axes: title={'center': 'V1'}>, <Axes: title={'center': 'V2'}>,
#         <Axes: title={'center': 'V3'}>]], dtype=object)

# %% [markdown]
# # 2.2 Min-Max Normalization

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
min_max = MinMaxScaler()

train_data_imputed_minmax_scaled = pd.DataFrame(min_max.fit_transform(train[continuous_features]), columns = continuous_features)

# %%
train_data_imputed_minmax_scaled.describe()
# Out:
#        TransactionDT  TransactionAmt          dist1             C1  \
# count  553287.000000   553287.000000  553287.000000  553287.000000
# mean        0.471825        0.004207       0.005257       0.002961
# std         0.292862        0.007478       0.023943       0.027718
# min         0.000000        0.000000       0.000000       0.000000
# 25%         0.196307        0.001337       0.000778       0.000213
# 50%         0.467494        0.002137       0.000778       0.000213
# 75%         0.719863        0.003906       0.000778       0.000640
# max         1.000000        1.000000       1.000000       1.000000
#
#                   C2             C3             D1             D2  \
# count  553287.000000  553287.000000  553287.000000  553287.000000
# mean        0.002647       0.000231       0.144903       0.214630
# std         0.026458       0.005980       0.245188       0.206728
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000176       0.000000       0.000000       0.140625
# 50%         0.000176       0.000000       0.003125       0.160938
# 75%         0.000527       0.000000       0.184375       0.162500
# max         1.000000       1.000000       1.000000       1.000000
#
#                   D3             V1             V2             V3
# count  553287.000000  553287.000000  553287.000000  553287.000000
# mean        0.023517       0.999971       0.128174       0.115984
# std         0.058198       0.005377       0.022671       0.027065
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.008547       1.000000       0.125000       0.111111
# 50%         0.009768       1.000000       0.125000       0.111111
# 75%         0.012210       1.000000       0.125000       0.111111
# max         1.000000       1.000000       1.000000       1.000000

# %%
train_data_imputed_minmax_scaled.hist(figsize=(20, 20))
# Out:
# array([[<Axes: title={'center': 'TransactionDT'}>,
#         <Axes: title={'center': 'TransactionAmt'}>,
#         <Axes: title={'center': 'dist1'}>],
#        [<Axes: title={'center': 'C1'}>, <Axes: title={'center': 'C2'}>,
#         <Axes: title={'center': 'C3'}>],
#        [<Axes: title={'center': 'D1'}>, <Axes: title={'center': 'D2'}>,
#         <Axes: title={'center': 'D3'}>],
#        [<Axes: title={'center': 'V1'}>, <Axes: title={'center': 'V2'}>,
#         <Axes: title={'center': 'V3'}>]], dtype=object)

# %% [markdown]
# # 3 Normalize Test Datasets

# %%
test.shape
# Out:
# (499806, 256)

# %%
test[continuous_features].describe()
# Out:
#        TransactionDT  TransactionAmt          dist1             C1  \
# count   4.998060e+05   499806.000000  499806.000000  499806.000000
# mean    2.694105e+07      134.506378      41.931313       9.440902
# std     4.756429e+06      245.788156     209.507788      70.005438
# min     1.840322e+07        0.018000       0.000000       0.000000
# 25%     2.278030e+07       40.000000       8.000000       1.000000
# 50%     2.721445e+07       67.950000       8.000000       1.000000
# 75%     3.135498e+07      125.000000       8.000000       3.000000
# max     3.421434e+07    10270.000000    8081.000000    2950.000000
#
#                   C2             C3             D1             D2  \
# count  499806.000000  499806.000000  499806.000000  499806.000000
# mean        9.973240       0.027777     107.606821     148.805268
# std        78.178931       0.229284     175.499411     150.413595
# min         0.000000       0.000000       0.000000       0.000000
# 25%         1.000000       0.000000       0.000000      94.000000
# 50%         1.000000       0.000000       6.000000     103.000000
# 75%         3.000000       0.000000     144.000000     130.000000
# max      3275.000000      31.000000     641.000000     641.000000
#
#                   D3             V1             V2             V3
# count  499806.000000  499806.000000  499806.000000  499806.000000
# mean       23.244561       0.999998       1.030764       1.057640
# std        65.208317       0.001414       0.204935       0.294446
# min         0.000000       0.000000       0.000000       0.000000
# 25%         5.000000       1.000000       1.000000       1.000000
# 50%         8.000000       1.000000       1.000000       1.000000
# 75%        12.000000       1.000000       1.000000       1.000000
# max      1076.000000       1.000000      11.000000      11.000000

# %%
test_contifeatures = pd.DataFrame((test[continuous_features]), columns=continuous_features)
test_contifeatures.hist(figsize=(20, 20))
# Out:
# array([[<Axes: title={'center': 'TransactionDT'}>,
#         <Axes: title={'center': 'TransactionAmt'}>,
#         <Axes: title={'center': 'dist1'}>],
#        [<Axes: title={'center': 'C1'}>, <Axes: title={'center': 'C2'}>,
#         <Axes: title={'center': 'C3'}>],
#        [<Axes: title={'center': 'D1'}>, <Axes: title={'center': 'D2'}>,
#         <Axes: title={'center': 'D3'}>],
#        [<Axes: title={'center': 'V1'}>, <Axes: title={'center': 'V2'}>,
#         <Axes: title={'center': 'V3'}>]], dtype=object)

# %% [markdown]
# # 3.1 Z-score Normalization

# %%
test_data_dropped_z_score_scaled = pd.DataFrame(scaler.fit_transform(test[continuous_features]), columns=continuous_features)
test_data_dropped_z_score_scaled.describe()
# Out:
#        TransactionDT  TransactionAmt         dist1            C1  \
# count   4.998060e+05    4.998060e+05  4.998060e+05  4.998060e+05
# mean   -1.067934e-16    1.589746e-16 -2.644245e-18 -9.055828e-18
# std     1.000001e+00    1.000001e+00  1.000001e+00  1.000001e+00
# min    -1.795010e+00   -5.471725e-01 -2.001422e-01 -1.348597e-01
# 25%    -8.747647e-01   -3.845038e-01 -1.619575e-01 -1.205751e-01
# 50%     5.747866e-02   -2.707878e-01 -1.619575e-01 -1.205751e-01
# 75%     9.279936e-01   -3.867716e-02 -1.619575e-01 -9.200583e-02
# max     1.529151e+00    4.123675e+01  3.837125e+01  4.200477e+01
#
#                  C2            C3            D1            D2            D3  \
# count  4.998060e+05  4.998060e+05  4.998060e+05  4.998060e+05  4.998060e+05
# mean   9.343710e-18  3.902038e-17  9.384226e-17  4.702065e-18  2.137787e-17
# std    1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min   -1.275695e-01 -1.211462e-01 -6.131470e-01 -9.893083e-01 -3.564666e-01
# 25%   -1.147783e-01 -1.211462e-01 -6.131470e-01 -3.643642e-01 -2.797891e-01
# 50%   -1.147783e-01 -1.211462e-01 -5.789588e-01 -3.045291e-01 -2.337827e-01
# 75%   -8.919598e-02 -1.211462e-01  2.073694e-01 -1.250239e-01 -1.724408e-01
# max    4.176355e+01  1.350824e+02  3.039291e+00  3.272279e+00  1.614451e+01
#
#                  V1            V2            V3
# count  4.998060e+05  4.998060e+05  4.998060e+05
# mean  -9.098962e-15  2.100202e-16  1.804573e-16
# std    1.000001e+00  1.000001e+00  1.000001e+00
# min   -7.069689e+02 -5.029718e+00 -3.591966e+00
# 25%    1.414489e-03 -1.501158e-01 -1.957586e-01
# 50%    1.414489e-03 -1.501158e-01 -1.957586e-01
# 75%    1.414489e-03 -1.501158e-01 -1.957586e-01
# max    1.414489e-03  4.864591e+01  3.376631e+01

# %%
test_data_dropped_z_score_scaled.hist(figsize=(20, 20))
# Out:
# array([[<Axes: title={'center': 'TransactionDT'}>,
#         <Axes: title={'center': 'TransactionAmt'}>,
#         <Axes: title={'center': 'dist1'}>],
#        [<Axes: title={'center': 'C1'}>, <Axes: title={'center': 'C2'}>,
#         <Axes: title={'center': 'C3'}>],
#        [<Axes: title={'center': 'D1'}>, <Axes: title={'center': 'D2'}>,
#         <Axes: title={'center': 'D3'}>],
#        [<Axes: title={'center': 'V1'}>, <Axes: title={'center': 'V2'}>,
#         <Axes: title={'center': 'V3'}>]], dtype=object)

# %% [markdown]
# # 3.2 Min-Max Normalization

# %%
min_max = MinMaxScaler()

# %%
test_data_imputed_minmax_scaled = pd.DataFrame(min_max.fit_transform(test[continuous_features]), columns = continuous_features)

# %%
test_data_imputed_minmax_scaled.describe()
# Out:
#        TransactionDT  TransactionAmt          dist1             C1  \
# count  499806.000000   499806.000000  499806.000000  499806.000000
# mean        0.539989        0.013095       0.005189       0.003200
# std         0.300828        0.023933       0.025926       0.023731
# min         0.000000        0.000000       0.000000       0.000000
# 25%         0.276835        0.003893       0.000990       0.000339
# 50%         0.557280        0.006615       0.000990       0.000339
# 75%         0.819155        0.012170       0.000990       0.001017
# max         1.000000        1.000000       1.000000       1.000000
#
#                   C2             C3             D1             D2  \
# count  499806.000000  499806.000000  499806.000000  499806.000000
# mean        0.003045       0.000896       0.167873       0.232146
# std         0.023871       0.007396       0.273790       0.234655
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000305       0.000000       0.000000       0.146646
# 50%         0.000305       0.000000       0.009360       0.160686
# 75%         0.000916       0.000000       0.224649       0.202808
# max         1.000000       1.000000       1.000000       1.000000
#
#                   D3             V1             V2             V3
# count  499806.000000  499806.000000  499806.000000  499806.000000
# mean        0.021603       0.999998       0.093706       0.096149
# std         0.060603       0.001414       0.018630       0.026768
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.004647       1.000000       0.090909       0.090909
# 50%         0.007435       1.000000       0.090909       0.090909
# 75%         0.011152       1.000000       0.090909       0.090909
# max         1.000000       1.000000       1.000000       1.000000

# %%
test_data_imputed_minmax_scaled.hist(figsize=(20, 20))
# Out:
# array([[<Axes: title={'center': 'TransactionDT'}>,
#         <Axes: title={'center': 'TransactionAmt'}>,
#         <Axes: title={'center': 'dist1'}>],
#        [<Axes: title={'center': 'C1'}>, <Axes: title={'center': 'C2'}>,
#         <Axes: title={'center': 'C3'}>],
#        [<Axes: title={'center': 'D1'}>, <Axes: title={'center': 'D2'}>,
#         <Axes: title={'center': 'D3'}>],
#        [<Axes: title={'center': 'V1'}>, <Axes: title={'center': 'V2'}>,
#         <Axes: title={'center': 'V3'}>]], dtype=object)
